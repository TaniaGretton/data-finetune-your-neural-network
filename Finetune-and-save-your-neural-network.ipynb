# %% [markdown]
# ## Imports

# %%
# Data manipulation
import time
import numpy as np
import pandas as pd

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error

# KERAS
from tensorflow.keras import models, layers
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.datasets import boston_housing
from tensorflow.keras.optimizers import Adam,RMSprop,Adagrad
from tensorflow.keras.optimizers.schedules import ExponentialDecay

# %% [markdown]
# # Fine-Tune your Neural Network and Save it
#
# 🎯 **Goals of this challenge**
#
# 1. ⚙️ **Fine-tune the optimizer** of a Neural Network
# 2. 💾 **Save**/**Load** a trained Neural Network
#
# 👩🏻‍🏫 Now that you have solid foundations about what Neural Networks are, how to design their architecture, and how to prevent them from overfitting, let's take a closer look at the `.compile(loss = ?, metrics = ?, activation = ?)` part.

# %% [markdown]
# ## (0) The Boston Housing Dataset
#
# 📚 `Tensorflow.Keras` has several built-in datasets that you can find [here](https://www.tensorflow.org/api_docs/python/tf/keras/datasets)
#
# 🏠 Out of those, we are going to use the **Boston Housing Dataset**.
#
# Our mission is to **predict the values of the houses in USD (thousands)**, and we will measure the performance of our models using the _Mean Absolute Error (MAE)_ metric.

# %% [markdown]
# ### (0.1) Loading the Dataset

# %%
# Loading the dataset:
(X_train, y_train), (X_test, y_test) = boston_housing.load_data()

# %%
# Shape of the dataset: 
(X_train.shape, y_train.shape), (X_test.shape, y_test.shape)
# Out:
# (((404, 13), (404,)), ((102, 13), (102,)))

# %% [markdown]
# ### (0.2) Quick Glance at the Target

# %%
# Distribution of the houses' prices in the training set
sns.histplot(y_train)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
# Null values and types of each feature:
pd.DataFrame(X_train).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       404 non-null    float64
#  1   1       404 non-null    float64
#  2   2       404 non-null    float64
#  3   3       404 non-null    float64
#  4   4       404 non-null    float64
#  5   5       404 non-null    float64
#  6   6       404 non-null    float64
#  7   7       404 non-null    float64
#  8   8       404 non-null    float64
#  9   9       404 non-null    float64
#  10  10      404 non-null    float64
#  11  11      404 non-null    float64
#  12  12      404 non-null    float64
# dtypes: float64(13)
# memory usage: 41.2 KB

# %%
# Statistics about the numerical columns
pd.DataFrame(X_train).describe()
# Out:
#                0           1           2           3           4           5   \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean     3.745111   11.480198   11.104431    0.061881    0.557356    6.267082
# std      9.240734   23.767711    6.811308    0.241238    0.117293    0.709788
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081437    0.000000    5.130000    0.000000    0.453000    5.874750
# 50%      0.268880    0.000000    9.690000    0.000000    0.538000    6.198500
# 75%      3.674808   12.500000   18.100000    0.000000    0.631000    6.609000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.725000
#
#                6           7           8           9           10          11  \
# count  404.000000  404.000000  404.000000  404.000000  404.000000  404.000000
# mean    69.010644    3.740271    9.440594  405.898515   18.475990  354.783168
# std     27.940665    2.030215    8.698360  166.374543    2.200382   94.111148
# min      2.900000    1.129600    1.000000  188.000000   12.600000    0.320000
# 25%     45.475000    2.077100    4.000000  279.000000   17.225000  374.672500
# 50%     78.500000    3.142300    5.000000  330.000000   19.100000  391.250000
# 75%     94.100000    5.118000   24.000000  666.000000   20.200000  396.157500
# max    100.000000   10.710300   24.000000  711.000000   22.000000  396.900000
#
#                12
# count  404.000000
# mean    12.740817
# std      7.254545
# min      1.730000
# 25%      6.890000
# 50%     11.395000
# 75%     17.092500
# max     37.970000

# %% [markdown]
# ### (0.3) Minimal Data Preprocessing
#
# 👉 Here, we don't have any duplicates or missing values. Let's do the bare minimum of data preprocessing, i.e. ***scaling**, and move on quickly to the modeling phase.

# %% [markdown]
# #### ❓Scaling your Features
#
# Standardize `X_train` and `X_test`.

# %%
SScaler = StandardScaler()
SScaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_scaled = SScaler.transform(X_train)
X_test_scaled = SScaler.transform(X_test)

# %% [markdown]
# ### (0.4) Baseline Model
#
# 🧑🏻‍🏫 In a regression task, the baseline model **always predicts the average value of `y_train`**
#
# <details>
#     <summary>Really?</summary>
#
# - 🐒  Yes, in most cases!
# - ❗️  Be aware that this is not the only possible way of building a baseline model
# - 💹  In Time Series, the baseline model predicts the **last seen value**

# %% [markdown]
# #### ❓Question: what would be the performance of the baseline model here?
#
# Before running any Machine Learning algorithm or advanced Deep Learning Neural Networks, it would be great to establish a benchmark score that you are supposed to beat. Otherwise, what is the point of running a fancy algorithm if you cannot beat this benchmark score on the testing set (other than showing off)?
#
# Compute the Mean Absolute Error on the testing set using a "dumb" prediction of the mean value of `y_train`, computed on the training set.

# %%
y_train_mean = np.mean(y_train)
dumb_pred = np.full(len(y_test), y_train_mean)
mean_absolute_error_test_baseline = mean_absolute_error(y_test, dumb_pred)
mean_absolute_error_test_baseline
# Out:
# 6.533042127742185

# %% [markdown]
# ## (1) The Neural Network

# %% [markdown]
# ### ❓Initializing a Neural Network with a Specific Architecture
#
# Write a function called `initialize_model` that generates a Neural Network with 3 layers:
# - Input layer: **10 neurons**, `relu` activation function, and the appropriate input dimension
# - Hidden layer: **7 neurons** and the `relu` activation function
# - Predictive layer: an appropriate layer corresponding to the problem we are trying to solve

# %%
def initialize_model():
    model = models.Sequential()
    model.add(layers.Dense(10, activation='relu', input_dim=X_train_scaled.shape[-1]))
    model.add(layers.Dense(7, activation='relu'))
    model.add(layers.Dense(1, activation='linear'))
    return model

model = initialize_model()
model.summary()
# Out:
# Model: "sequential_22"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_69 (Dense)            (None, 10)                140
#
#  dense_70 (Dense)            (None, 7)                 77
#
#  dense_71 (Dense)            (None, 1)                 8
#
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### ❓Number of Parameters
#
# How many parameters do we have in this model?
# 1. Compute this number yourself
# 2. Double-check your answer with `model.summary()`
#
# We already covered the question about the number of parameters in a fully connected/dense network during **Deep Learning > 01. Fundamentals of Deep Learning** but it is always good to make sure you master the foundations of a new discipline 😉

# %% [markdown]
# ##### 💡Answer
#
# <details>
#     <summary>Click here</summary>
#
# - Each house has `X_train.shape[-1]` = 13 features
# - Remember that a neuron is a linear regression combined with an activation function, so we will have 13 weights and 1 bias
#
# 1. First layer: **10 neurons** $\times$ (13 weights + 1 bias ) = 140 params
# 2. Second layer: **7 neurons** $\times$ (10 weights + 1 bias ) = 77 params
# 3. Third layer: **1 neuron** $\times$ (7 weights + 1 bias) = 8 params
# </details>

# %% [markdown]
# ## (2) The Optimizer

# %% [markdown]
# ### ❓Compiling Method
#
# Write a function that:
# 1. takes _both_ a **model** and an **optimizer** as arguments
# 2. **compiles** the model
# 3. returns the compiled model
#
# Please select wisely:
# - the **Loss Function** to be optimized
# - the **metrics** on which the model should be evaluated

# %%
def compile_model(model, optimizer_name):
    model.compile(loss = "mse", optimizer = optimizer_name,metrics = ["mae"])
    return model

# %% [markdown]
# ### ❓Evaluating the Model
#
# - Initialize the model and compile it with the `adam` optimizer
# - Fit it on the training data
# - Evaluate your model on the testing data
#
# Don't forget to use an Early Stopping criterion to avoid overfitting!
#
# <details>
#     <summary>Notes</summary>
#
# As we saw in the **"How to prevent overfitting"** challenge,  you could also use L2 penalties and Dropout Layers to prevent overfitting but:
# - Early Stopping is the easiest and quickest code to implement, you just declare `es = EarlyStopping()` and call it back in the `.fit()` step
# - The main goal of this challenge is to understand the **impact of the optimizer**, so stay focused 😉
# </details>

# %%
model = compile_model(model,"adam")
es = EarlyStopping(patience=20,restore_best_weights=True)

# %%
# %%time
history = model.fit(X_train_scaled,
    y_train,
    epochs = 500,
    batch_size = 16, 
    verbose = 1, 
    callbacks = [es])
# Out:
# Epoch 1/500
#  1/26 [>.............................] - ETA: 4s - loss: 435.6238 - mae: 20.2738WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 626us/step - loss: 549.1472 - mae: 21.7009
# Epoch 2/500
#  1/26 [>.............................] - ETA: 0s - loss: 490.0270 - mae: 21.3685WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 506us/step - loss: 531.5047 - mae: 21.3264
# Epoch 3/500
#  1/26 [>.............................] - ETA: 0s - loss: 653.3487 - mae: 22.0615WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 476us/step - loss: 509.4608 - mae: 20.8627
# Epoch 4/500
#  1/26 [>.............................] - ETA: 0s - loss: 531.7394 - mae: 20.5528WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 458us/step - loss: 481.1100 - mae: 20.2445
# Epoch 5/500
#  1/26 [>.............................] - ETA: 0s - loss: 397.3546 - mae: 17.4152WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 443us/step - loss: 442.9686 - mae: 19.3775
# Epoch 6/500
#  1/26 [>.............................] - ETA: 0s - loss: 375.5296 - mae: 18.2808WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 452us/step - loss: 395.0415 - mae: 18.2043
# Epoch 7/500
#  1/26 [>.............................] - ETA: 0s - loss: 421.4111 - mae: 18.3568WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 437us/step - loss: 338.4893 - mae: 16.7152
# Epoch 8/500
#  1/26 [>.............................] - ETA: 0s - loss: 201.4220 - mae: 13.5319WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 444us/step - loss: 275.4872 - mae: 14.8145
# Epoch 9/500
#  1/26 [>.............................] - ETA: 0s - loss: 264.4502 - mae: 13.6807WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 444us/step - loss: 212.2104 - mae: 12.6046
# Epoch 10/500
#  1/26 [>.............................] - ETA: 0s - loss: 131.7818 - mae: 10.2626WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 439us/step - loss: 154.8905 - mae: 10.2635
# Epoch 11/500
#  1/26 [>.............................] - ETA: 0s - loss: 123.8261 - mae: 9.7461WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 442us/step - loss: 111.2692 - mae: 8.1983
# Epoch 12/500
#  1/26 [>.............................] - ETA: 0s - loss: 163.6950 - mae: 9.6022WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 442us/step - loss: 83.8338 - mae: 6.7263
# Epoch 13/500
#  1/26 [>.............................] - ETA: 0s - loss: 314.7487 - mae: 13.1990WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 436us/step - loss: 68.4335 - mae: 5.8034
# Epoch 14/500
#  1/26 [>.............................] - ETA: 0s - loss: 31.8159 - mae: 4.7462WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 436us/step - loss: 58.5767 - mae: 5.2644
# Epoch 15/500
#  1/26 [>.............................] - ETA: 0s - loss: 174.7492 - mae: 8.7148WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 434us/step - loss: 53.1001 - mae: 4.9348
# Epoch 16/500
#  1/26 [>.............................] - ETA: 0s - loss: 87.4043 - mae: 5.5718WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 432us/step - loss: 48.0458 - mae: 4.6738
# Epoch 17/500
#  1/26 [>.............................] - ETA: 0s - loss: 31.1809 - mae: 4.6930WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 455us/step - loss: 44.9638 - mae: 4.4892
# Epoch 18/500
#  1/26 [>.............................] - ETA: 0s - loss: 17.9889 - mae: 3.1768WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 439us/step - loss: 42.2698 - mae: 4.3709
# Epoch 19/500
#  1/26 [>.............................] - ETA: 0s - loss: 22.8441 - mae: 3.7227WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 435us/step - loss: 40.3451 - mae: 4.2717
# Epoch 20/500
#  1/26 [>.............................] - ETA: 0s - loss: 64.6857 - mae: 4.2020WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 452us/step - loss: 38.6999 - mae: 4.2071
# Epoch 21/500
#  1/26 [>.............................] - ETA: 0s - loss: 54.3514 - mae: 4.6468WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 436us/step - loss: 37.3529 - mae: 4.1483
# Epoch 22/500
#  1/26 [>.............................] - ETA: 0s - loss: 31.2135 - mae: 3.5129WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 436us/step - loss: 35.9587 - mae: 4.0762
# Epoch 23/500
#  1/26 [>.............................] - ETA: 0s - loss: 20.6114 - mae: 4.1149WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 429us/step - loss: 34.6442 - mae: 4.0164
# Epoch 24/500
#  1/26 [>.............................] - ETA: 0s - loss: 10.6684 - mae: 2.6383WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 435us/step - loss: 33.5839 - mae: 3.9697
# Epoch 25/500
#  1/26 [>.............................] - ETA: 0s - loss: 17.0641 - mae: 3.4638WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 456us/step - loss: 32.7228 - mae: 3.9301
# Epoch 26/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.6963 - mae: 1.7515WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 439us/step - loss: 31.8532 - mae: 3.8850
# Epoch 27/500
#  1/26 [>.............................] - ETA: 0s - loss: 18.8883 - mae: 3.4144WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 445us/step - loss: 31.1130 - mae: 3.8285
# Epoch 28/500
#  1/26 [>.............................] - ETA: 0s - loss: 58.0626 - mae: 5.4705WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 435us/step - loss: 30.3210 - mae: 3.7830
# Epoch 29/500
#  1/26 [>.............................] - ETA: 0s - loss: 15.5495 - mae: 3.2489WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 432us/step - loss: 29.6232 - mae: 3.7490
# Epoch 30/500
#  1/26 [>.............................] - ETA: 0s - loss: 14.2750 - mae: 2.9013WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 435us/step - loss: 28.8813 - mae: 3.6971
# Epoch 31/500
#  1/26 [>.............................] - ETA: 0s - loss: 16.6939 - mae: 3.2641WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 428us/step - loss: 28.2284 - mae: 3.6706
# Epoch 32/500
#  1/26 [>.............................] - ETA: 0s - loss: 24.8213 - mae: 4.1128WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 433us/step - loss: 27.4834 - mae: 3.6498
# Epoch 33/500
#  1/26 [>.............................] - ETA: 0s - loss: 8.7143 - mae: 2.3964WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 428us/step - loss: 26.8109 - mae: 3.6098
# Epoch 34/500
#  1/26 [>.............................] - ETA: 0s - loss: 28.0590 - mae: 2.9902WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 428us/step - loss: 26.2653 - mae: 3.5878
# Epoch 35/500
#  1/26 [>.............................] - ETA: 0s - loss: 78.0918 - mae: 5.5120WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 447us/step - loss: 25.4850 - mae: 3.5235
# Epoch 36/500
#  1/26 [>.............................] - ETA: 0s - loss: 17.7909 - mae: 3.5002WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 422us/step - loss: 24.8908 - mae: 3.4890
# Epoch 37/500
#  1/26 [>.............................] - ETA: 0s - loss: 27.9711 - mae: 3.3280WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 1ms/step - loss: 24.3187 - mae: 3.4509
# Epoch 38/500
#  1/26 [>.............................] - ETA: 0s - loss: 14.1505 - mae: 2.6094WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 442us/step - loss: 23.8918 - mae: 3.4145
# Epoch 39/500
#  1/26 [>.............................] - ETA: 0s - loss: 23.6518 - mae: 3.2088WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 445us/step - loss: 23.3681 - mae: 3.3540
# Epoch 40/500
#  1/26 [>.............................] - ETA: 0s - loss: 15.3167 - mae: 2.9803WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 435us/step - loss: 22.8804 - mae: 3.3225
# Epoch 41/500
#  1/26 [>.............................] - ETA: 0s - loss: 7.8771 - mae: 2.2120WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 429us/step - loss: 22.4243 - mae: 3.2921
# Epoch 42/500
#  1/26 [>.............................] - ETA: 0s - loss: 13.8349 - mae: 2.8556WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 446us/step - loss: 21.9652 - mae: 3.2561
# Epoch 43/500
#  1/26 [>.............................] - ETA: 0s - loss: 68.3404 - mae: 4.4130WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 429us/step - loss: 21.5691 - mae: 3.2362
# Epoch 44/500
#  1/26 [>.............................] - ETA: 0s - loss: 20.2456 - mae: 3.8083WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 438us/step - loss: 21.1132 - mae: 3.1737
# Epoch 45/500
#  1/26 [>.............................] - ETA: 0s - loss: 25.7395 - mae: 3.6378WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 426us/step - loss: 20.5928 - mae: 3.1449
# Epoch 46/500
#  1/26 [>.............................] - ETA: 0s - loss: 29.1972 - mae: 3.8415WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 440us/step - loss: 20.1731 - mae: 3.1120
# Epoch 47/500
#  1/26 [>.............................] - ETA: 0s - loss: 23.3348 - mae: 3.3859WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 459us/step - loss: 19.6504 - mae: 3.0665
# Epoch 48/500
#  1/26 [>.............................] - ETA: 0s - loss: 29.7140 - mae: 3.9287WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 440us/step - loss: 19.2294 - mae: 3.0269
# Epoch 49/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.7960 - mae: 1.9598WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 441us/step - loss: 18.8086 - mae: 2.9960
# Epoch 50/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.5328 - mae: 1.7023WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 447us/step - loss: 18.3414 - mae: 2.9726
# Epoch 51/500
#  1/26 [>.............................] - ETA: 0s - loss: 61.5364 - mae: 4.4530WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 439us/step - loss: 18.0674 - mae: 2.9706
# Epoch 52/500
#  1/26 [>.............................] - ETA: 0s - loss: 9.1078 - mae: 2.2148WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 429us/step - loss: 17.6125 - mae: 2.9288
# Epoch 53/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.7868 - mae: 1.3350WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 417us/step - loss: 17.2251 - mae: 2.8789
# Epoch 54/500
#  1/26 [>.............................] - ETA: 0s - loss: 11.5714 - mae: 2.8361WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 444us/step - loss: 16.8651 - mae: 2.8361
# Epoch 55/500
#  1/26 [>.............................] - ETA: 0s - loss: 57.4405 - mae: 4.3024WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 422us/step - loss: 16.5574 - mae: 2.8162
# Epoch 56/500
#  1/26 [>.............................] - ETA: 0s - loss: 9.2005 - mae: 2.3692WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 446us/step - loss: 16.2540 - mae: 2.7741
# Epoch 57/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.5841 - mae: 1.4916WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 438us/step - loss: 15.9540 - mae: 2.7550
# Epoch 58/500
#  1/26 [>.............................] - ETA: 0s - loss: 65.7081 - mae: 4.9374WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 426us/step - loss: 15.6822 - mae: 2.7511
# Epoch 59/500
#  1/26 [>.............................] - ETA: 0s - loss: 14.7993 - mae: 2.9699WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 454us/step - loss: 15.2804 - mae: 2.7090
# Epoch 60/500
#  1/26 [>.............................] - ETA: 0s - loss: 23.7968 - mae: 3.3447WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 423us/step - loss: 14.9553 - mae: 2.6840
# Epoch 61/500
#  1/26 [>.............................] - ETA: 0s - loss: 8.5688 - mae: 2.1724WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 428us/step - loss: 14.6777 - mae: 2.6383
# Epoch 62/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.9273 - mae: 1.6718WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 437us/step - loss: 14.3838 - mae: 2.6328
# Epoch 63/500
#  1/26 [>.............................] - ETA: 0s - loss: 34.4083 - mae: 3.4813WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 433us/step - loss: 14.1154 - mae: 2.6001
# Epoch 64/500
#  1/26 [>.............................] - ETA: 0s - loss: 28.8300 - mae: 3.3144WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 430us/step - loss: 13.8809 - mae: 2.5787
# Epoch 65/500
#  1/26 [>.............................] - ETA: 0s - loss: 10.6180 - mae: 2.6545WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 425us/step - loss: 13.7115 - mae: 2.5496
# Epoch 66/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.1163 - mae: 1.6120WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 436us/step - loss: 13.4270 - mae: 2.5513
# Epoch 67/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.0169 - mae: 2.0087WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 441us/step - loss: 13.1661 - mae: 2.5255
# Epoch 68/500
#  1/26 [>.............................] - ETA: 0s - loss: 7.3731 - mae: 2.2932WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 454us/step - loss: 12.9870 - mae: 2.5062
# Epoch 69/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.3288 - mae: 1.6536WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 1ms/step - loss: 12.8570 - mae: 2.4756
# Epoch 70/500
#  1/26 [>.............................] - ETA: 0s - loss: 15.5605 - mae: 2.8951WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 438us/step - loss: 12.6920 - mae: 2.4741
# Epoch 71/500
#  1/26 [>.............................] - ETA: 0s - loss: 7.1398 - mae: 2.2477WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 423us/step - loss: 12.4744 - mae: 2.4522
# Epoch 72/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.1238 - mae: 2.0027WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 427us/step - loss: 12.2821 - mae: 2.4259
# Epoch 73/500
#  1/26 [>.............................] - ETA: 0s - loss: 8.0874 - mae: 2.1903WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 444us/step - loss: 12.1138 - mae: 2.4124
# Epoch 74/500
#  1/26 [>.............................] - ETA: 0s - loss: 19.6692 - mae: 3.3063WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 432us/step - loss: 11.9934 - mae: 2.4041
# Epoch 75/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.7520 - mae: 1.9250WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 433us/step - loss: 11.8538 - mae: 2.4019
# Epoch 76/500
#  1/26 [>.............................] - ETA: 0s - loss: 8.4725 - mae: 2.3638WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 451us/step - loss: 11.7011 - mae: 2.3927
# Epoch 77/500
#  1/26 [>.............................] - ETA: 0s - loss: 9.9517 - mae: 2.6768WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 424us/step - loss: 11.6605 - mae: 2.3711
# Epoch 78/500
#  1/26 [>.............................] - ETA: 0s - loss: 13.4405 - mae: 2.7781WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 438us/step - loss: 11.5128 - mae: 2.3786
# Epoch 79/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.1162 - mae: 1.8624WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 439us/step - loss: 11.3660 - mae: 2.3499
# Epoch 80/500
#  1/26 [>.............................] - ETA: 0s - loss: 13.2325 - mae: 2.6271WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 440us/step - loss: 11.2264 - mae: 2.3366
# Epoch 81/500
#  1/26 [>.............................] - ETA: 0s - loss: 28.5641 - mae: 3.7487WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 435us/step - loss: 11.0842 - mae: 2.3166
# Epoch 82/500
#  1/26 [>.............................] - ETA: 0s - loss: 7.4471 - mae: 2.2716WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 420us/step - loss: 10.9844 - mae: 2.3065
# Epoch 83/500
#  1/26 [>.............................] - ETA: 0s - loss: 9.8431 - mae: 2.7049WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 440us/step - loss: 10.8971 - mae: 2.3092
# Epoch 84/500
#  1/26 [>.............................] - ETA: 0s - loss: 8.5179 - mae: 2.4818WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 446us/step - loss: 10.8085 - mae: 2.2923
# Epoch 85/500
#  1/26 [>.............................] - ETA: 0s - loss: 8.9790 - mae: 2.1970WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 454us/step - loss: 10.7346 - mae: 2.2905
# Epoch 86/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.0077 - mae: 1.4886WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 451us/step - loss: 10.6440 - mae: 2.2829
# Epoch 87/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.5321 - mae: 1.2409WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 953us/step - loss: 10.5114 - mae: 2.2641
# Epoch 88/500
#  1/26 [>.............................] - ETA: 0s - loss: 12.1438 - mae: 2.6001WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 440us/step - loss: 10.5323 - mae: 2.2590
# Epoch 89/500
#  1/26 [>.............................] - ETA: 0s - loss: 12.5606 - mae: 2.4812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 435us/step - loss: 10.3776 - mae: 2.2445
# Epoch 90/500
#  1/26 [>.............................] - ETA: 0s - loss: 11.2867 - mae: 2.7935WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 431us/step - loss: 10.2804 - mae: 2.2363
# Epoch 91/500
#  1/26 [>.............................] - ETA: 0s - loss: 8.4429 - mae: 2.5577WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 420us/step - loss: 10.2603 - mae: 2.2287
# Epoch 92/500
#  1/26 [>.............................] - ETA: 0s - loss: 18.7337 - mae: 2.6869WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 444us/step - loss: 10.1678 - mae: 2.2227
# Epoch 93/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.6270 - mae: 2.2053WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 468us/step - loss: 10.1168 - mae: 2.2280
# Epoch 94/500
#  1/26 [>.............................] - ETA: 0s - loss: 8.0005 - mae: 2.3543WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 426us/step - loss: 10.0818 - mae: 2.2098
# Epoch 95/500
#  1/26 [>.............................] - ETA: 0s - loss: 21.8006 - mae: 2.8733WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 435us/step - loss: 9.9789 - mae: 2.2167
# Epoch 96/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.4282 - mae: 2.0520WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 433us/step - loss: 9.9475 - mae: 2.2065
# Epoch 97/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.8424 - mae: 1.7835WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 424us/step - loss: 9.8746 - mae: 2.2001
# Epoch 98/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.8035 - mae: 2.2929WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 437us/step - loss: 9.8366 - mae: 2.2007
# Epoch 99/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.8774 - mae: 1.5848WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 430us/step - loss: 9.8053 - mae: 2.1830
# Epoch 100/500
#  1/26 [>.............................] - ETA: 0s - loss: 20.0751 - mae: 3.0984WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 437us/step - loss: 9.7343 - mae: 2.1901
# Epoch 101/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.3575 - mae: 1.3916WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 444us/step - loss: 9.6843 - mae: 2.1771
# Epoch 102/500
#  1/26 [>.............................] - ETA: 0s - loss: 36.0608 - mae: 3.0262WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 448us/step - loss: 9.6444 - mae: 2.1645
# Epoch 103/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.5636 - mae: 1.9538WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 440us/step - loss: 9.5703 - mae: 2.1679
# Epoch 104/500
#  1/26 [>.............................] - ETA: 0s - loss: 9.4900 - mae: 2.1732WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 444us/step - loss: 9.5721 - mae: 2.1706
# Epoch 105/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.8683 - mae: 1.9502WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 443us/step - loss: 9.5518 - mae: 2.1663
# Epoch 106/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.7203 - mae: 1.9636WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 429us/step - loss: 9.4715 - mae: 2.1552
# Epoch 107/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.7126 - mae: 1.8149WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 437us/step - loss: 9.4852 - mae: 2.1600
# Epoch 108/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.2015 - mae: 1.8644WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 432us/step - loss: 9.4344 - mae: 2.1634
# Epoch 109/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.3250 - mae: 1.8795WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 1ms/step - loss: 9.3596 - mae: 2.1451
# Epoch 110/500
#  1/26 [>.............................] - ETA: 0s - loss: 13.0290 - mae: 2.2329WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 446us/step - loss: 9.3238 - mae: 2.1294
# Epoch 111/500
#  1/26 [>.............................] - ETA: 0s - loss: 12.9789 - mae: 2.6463WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 436us/step - loss: 9.3201 - mae: 2.1490
# Epoch 112/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.3987 - mae: 1.9277WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 437us/step - loss: 9.2874 - mae: 2.1433
# Epoch 113/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.1276 - mae: 1.9010WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 458us/step - loss: 9.2230 - mae: 2.1271
# Epoch 114/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.8163 - mae: 1.9605WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 456us/step - loss: 9.2335 - mae: 2.1117
# Epoch 115/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.5371 - mae: 1.5448WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 445us/step - loss: 9.1678 - mae: 2.1207
# Epoch 116/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.5283 - mae: 1.6305WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 420us/step - loss: 9.1189 - mae: 2.1155
# Epoch 117/500
#  1/26 [>.............................] - ETA: 0s - loss: 12.1821 - mae: 2.7069WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 445us/step - loss: 9.1421 - mae: 2.1114
# Epoch 118/500
#  1/26 [>.............................] - ETA: 0s - loss: 12.9275 - mae: 2.5190WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 432us/step - loss: 9.2286 - mae: 2.1362
# Epoch 119/500
#  1/26 [>.............................] - ETA: 0s - loss: 8.1168 - mae: 2.3042WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 427us/step - loss: 9.0565 - mae: 2.1077
# Epoch 120/500
#  1/26 [>.............................] - ETA: 0s - loss: 18.5904 - mae: 2.5286WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 442us/step - loss: 9.1340 - mae: 2.1444
# Epoch 121/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.9456 - mae: 1.8157WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 490us/step - loss: 8.9763 - mae: 2.1122
# Epoch 122/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.4799 - mae: 1.9027WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 432us/step - loss: 8.9793 - mae: 2.0924
# Epoch 123/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.8006 - mae: 1.7321WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 448us/step - loss: 9.0068 - mae: 2.1056
# Epoch 124/500
#  1/26 [>.............................] - ETA: 0s - loss: 7.6942 - mae: 2.1257WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 455us/step - loss: 8.9283 - mae: 2.0962
# Epoch 125/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.7926 - mae: 1.6755WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 466us/step - loss: 8.8992 - mae: 2.0908
# Epoch 126/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.5141 - mae: 1.4884WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 434us/step - loss: 8.8744 - mae: 2.0940
# Epoch 127/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.5860 - mae: 1.8610WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 444us/step - loss: 8.9798 - mae: 2.0908
# Epoch 128/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.5615 - mae: 1.7538WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 441us/step - loss: 8.8339 - mae: 2.0996
# Epoch 129/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.4576 - mae: 1.4446WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 430us/step - loss: 8.8232 - mae: 2.0838
# Epoch 130/500
#  1/26 [>.............................] - ETA: 0s - loss: 7.6676 - mae: 2.1899WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 1ms/step - loss: 8.7925 - mae: 2.0768
# Epoch 131/500
#  1/26 [>.............................] - ETA: 0s - loss: 8.6122 - mae: 1.8067WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 457us/step - loss: 8.8078 - mae: 2.0886
# Epoch 132/500
#  1/26 [>.............................] - ETA: 0s - loss: 9.0290 - mae: 2.0184WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 433us/step - loss: 8.7697 - mae: 2.0740
# Epoch 133/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.3782 - mae: 1.7517WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 437us/step - loss: 8.7068 - mae: 2.0709
# Epoch 134/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.0101 - mae: 1.9839WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 448us/step - loss: 8.6566 - mae: 2.0613
# Epoch 135/500
#  1/26 [>.............................] - ETA: 0s - loss: 17.8145 - mae: 2.6879WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 426us/step - loss: 8.6842 - mae: 2.0639
# Epoch 136/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.7556 - mae: 1.6192WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 439us/step - loss: 8.6381 - mae: 2.0570
# Epoch 137/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.5820 - mae: 2.1789WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 432us/step - loss: 8.6312 - mae: 2.0505
# Epoch 138/500
#  1/26 [>.............................] - ETA: 0s - loss: 7.8364 - mae: 2.1876WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 452us/step - loss: 8.6314 - mae: 2.0603
# Epoch 139/500
#  1/26 [>.............................] - ETA: 0s - loss: 7.7597 - mae: 2.3354WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 440us/step - loss: 8.5738 - mae: 2.0453
# Epoch 140/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.0895 - mae: 1.6305WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 433us/step - loss: 8.5572 - mae: 2.0529
# Epoch 141/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.9294 - mae: 2.1303WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 425us/step - loss: 8.6672 - mae: 2.0802
# Epoch 142/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.1449 - mae: 1.9597WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 448us/step - loss: 8.6659 - mae: 2.0557
# Epoch 143/500
#  1/26 [>.............................] - ETA: 0s - loss: 11.2666 - mae: 2.3413WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 438us/step - loss: 8.5622 - mae: 2.0626
# Epoch 144/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.4316 - mae: 1.6719WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 463us/step - loss: 8.5905 - mae: 2.0376
# Epoch 145/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.7227 - mae: 1.3644WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 438us/step - loss: 8.4586 - mae: 2.0456
# Epoch 146/500
#  1/26 [>.............................] - ETA: 0s - loss: 13.9377 - mae: 2.7345WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 439us/step - loss: 8.4515 - mae: 2.0467
# Epoch 147/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.3045 - mae: 1.5178WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 449us/step - loss: 8.5940 - mae: 2.0608
# Epoch 148/500
#  1/26 [>.............................] - ETA: 0s - loss: 8.8629 - mae: 1.8692WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 1ms/step - loss: 8.4013 - mae: 2.0347
# Epoch 149/500
#  1/26 [>.............................] - ETA: 0s - loss: 12.0385 - mae: 2.8410WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 438us/step - loss: 8.4155 - mae: 2.0296
# Epoch 150/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.1761 - mae: 1.6826WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 435us/step - loss: 8.4105 - mae: 2.0358
# Epoch 151/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.7312 - mae: 1.5383WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 438us/step - loss: 8.3583 - mae: 2.0345
# Epoch 152/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.8003 - mae: 2.0311WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 435us/step - loss: 8.4388 - mae: 2.0297
# Epoch 153/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.8641 - mae: 1.7724WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 448us/step - loss: 8.3246 - mae: 2.0326
# Epoch 154/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.7365 - mae: 1.5195WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 431us/step - loss: 8.4463 - mae: 2.0594
# Epoch 155/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.0067 - mae: 1.4039WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 457us/step - loss: 8.3087 - mae: 2.0246
# Epoch 156/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.3519 - mae: 1.8176WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 430us/step - loss: 8.3103 - mae: 2.0303
# Epoch 157/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.8662 - mae: 1.7200WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 443us/step - loss: 8.2719 - mae: 2.0225
# Epoch 158/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.0606 - mae: 1.8265WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 426us/step - loss: 8.3497 - mae: 2.0357
# Epoch 159/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.6261 - mae: 1.7340WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 442us/step - loss: 8.2352 - mae: 2.0288
# Epoch 160/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.5373 - mae: 1.2852WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 444us/step - loss: 8.2369 - mae: 2.0336
# Epoch 161/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.9894 - mae: 1.8994WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# ...
# 26/26 [==============================] - 0s 488us/step - loss: 6.5500 - mae: 1.8284
# Epoch 448/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.0561 - mae: 1.5245WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 488us/step - loss: 6.5501 - mae: 1.8153
# Epoch 449/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.3361 - mae: 1.5343WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 470us/step - loss: 6.5820 - mae: 1.8254
# Epoch 450/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.3664 - mae: 1.8962WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 476us/step - loss: 6.5361 - mae: 1.8166
# Epoch 451/500
#  1/26 [>.............................] - ETA: 0s - loss: 1.6525 - mae: 1.1066WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 1ms/step - loss: 6.6111 - mae: 1.8175
# Epoch 452/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.0860 - mae: 1.2483WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 498us/step - loss: 6.5095 - mae: 1.8096
# Epoch 453/500
#  1/26 [>.............................] - ETA: 0s - loss: 23.2216 - mae: 2.5276WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 467us/step - loss: 6.5521 - mae: 1.8225
# Epoch 454/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.0930 - mae: 1.1218WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 564us/step - loss: 6.5193 - mae: 1.8271
# Epoch 455/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.5977 - mae: 1.3327WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 543us/step - loss: 6.4835 - mae: 1.8176
# Epoch 456/500
#  1/26 [>.............................] - ETA: 0s - loss: 1.6039 - mae: 0.9599WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 494us/step - loss: 6.4477 - mae: 1.8157
# Epoch 457/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.4258 - mae: 1.9731WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 541us/step - loss: 6.4341 - mae: 1.8065
# Epoch 458/500
#  1/26 [>.............................] - ETA: 0s - loss: 9.3524 - mae: 2.0099WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 569us/step - loss: 6.4631 - mae: 1.8160
# Epoch 459/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.8871 - mae: 1.9079WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 563us/step - loss: 6.4710 - mae: 1.7962
# Epoch 460/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.2736 - mae: 1.0858WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 629us/step - loss: 6.4832 - mae: 1.8179
# Epoch 461/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.2474 - mae: 1.6705WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 653us/step - loss: 6.5048 - mae: 1.8132
# Epoch 462/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.5700 - mae: 1.2384WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 508us/step - loss: 6.4739 - mae: 1.8049
# Epoch 463/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.3145 - mae: 1.4747WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 2ms/step - loss: 6.4574 - mae: 1.8084
# Epoch 464/500
#  1/26 [>.............................] - ETA: 0s - loss: 10.7599 - mae: 2.4231WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 563us/step - loss: 6.4309 - mae: 1.8043
# Epoch 465/500
#  1/26 [>.............................] - ETA: 0s - loss: 8.6381 - mae: 2.1823WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 514us/step - loss: 6.4288 - mae: 1.8146
# Epoch 466/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.3134 - mae: 1.3254WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 721us/step - loss: 6.4260 - mae: 1.8027
# Epoch 467/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.3256 - mae: 1.5374WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 1ms/step - loss: 6.4167 - mae: 1.8084
# Epoch 468/500
#  1/26 [>.............................] - ETA: 0s - loss: 8.4064 - mae: 1.8723WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 497us/step - loss: 6.5326 - mae: 1.8408
# Epoch 469/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.0618 - mae: 1.1578WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 505us/step - loss: 6.4267 - mae: 1.8111
# Epoch 470/500
#  1/26 [>.............................] - ETA: 0s - loss: 21.1029 - mae: 2.3558WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 501us/step - loss: 6.4461 - mae: 1.7921
# Epoch 471/500
#  1/26 [>.............................] - ETA: 0s - loss: 10.4707 - mae: 2.0359WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 532us/step - loss: 6.4102 - mae: 1.8172
# Epoch 472/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.3300 - mae: 1.3856WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 551us/step - loss: 6.3755 - mae: 1.8002
# Epoch 473/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.2314 - mae: 1.4599WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 551us/step - loss: 6.4684 - mae: 1.8393
# Epoch 474/500
#  1/26 [>.............................] - ETA: 0s - loss: 8.1061 - mae: 2.2314WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 590us/step - loss: 6.4911 - mae: 1.8170
# Epoch 475/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.3104 - mae: 1.6615WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 1ms/step - loss: 6.4194 - mae: 1.8068
# Epoch 476/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.6120 - mae: 1.6949WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 798us/step - loss: 6.3666 - mae: 1.7871
# Epoch 477/500
#  1/26 [>.............................] - ETA: 0s - loss: 11.3032 - mae: 2.2328WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 515us/step - loss: 6.4145 - mae: 1.8112
# Epoch 478/500
#  1/26 [>.............................] - ETA: 0s - loss: 7.8891 - mae: 2.1438WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 520us/step - loss: 6.3704 - mae: 1.7998
# Epoch 479/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.8975 - mae: 1.5403WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 473us/step - loss: 6.3591 - mae: 1.7829
# Epoch 480/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.7937 - mae: 1.3327WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 585us/step - loss: 6.3612 - mae: 1.8021
# Epoch 481/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.5262 - mae: 1.5907WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 530us/step - loss: 6.3811 - mae: 1.7865
# Epoch 482/500
#  1/26 [>.............................] - ETA: 0s - loss: 4.9196 - mae: 1.5667WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 513us/step - loss: 6.3766 - mae: 1.8003
# Epoch 483/500
#  1/26 [>.............................] - ETA: 0s - loss: 7.1767 - mae: 1.7716WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 524us/step - loss: 6.4644 - mae: 1.8286
# Epoch 484/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.2128 - mae: 1.1038WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 552us/step - loss: 6.3528 - mae: 1.7855
# Epoch 485/500
#  1/26 [>.............................] - ETA: 0s - loss: 25.7366 - mae: 2.7119WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 513us/step - loss: 6.3403 - mae: 1.8002
# Epoch 486/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.7156 - mae: 1.3991WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 550us/step - loss: 6.3436 - mae: 1.7848
# Epoch 487/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.0286 - mae: 1.3678WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 526us/step - loss: 6.3689 - mae: 1.8166
# Epoch 488/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.3215 - mae: 1.1659WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 692us/step - loss: 6.3680 - mae: 1.8067
# Epoch 489/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.7165 - mae: 1.9625WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 518us/step - loss: 6.3471 - mae: 1.7900
# Epoch 490/500
#  1/26 [>.............................] - ETA: 0s - loss: 8.3491 - mae: 1.8796WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 535us/step - loss: 6.4320 - mae: 1.7965
# Epoch 491/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.1896 - mae: 1.1472WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 514us/step - loss: 6.3729 - mae: 1.8093
# Epoch 492/500
#  1/26 [>.............................] - ETA: 0s - loss: 2.9860 - mae: 1.2271WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 2ms/step - loss: 6.2979 - mae: 1.7962
# Epoch 493/500
#  1/26 [>.............................] - ETA: 0s - loss: 1.3463 - mae: 0.9634WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 534us/step - loss: 6.4215 - mae: 1.8040
# Epoch 494/500
#  1/26 [>.............................] - ETA: 0s - loss: 10.2355 - mae: 2.2348WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 543us/step - loss: 6.3444 - mae: 1.8033
# Epoch 495/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.0571 - mae: 1.4664WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 559us/step - loss: 6.3255 - mae: 1.7756
# Epoch 496/500
#  1/26 [>.............................] - ETA: 0s - loss: 25.2676 - mae: 2.9845WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 533us/step - loss: 6.3123 - mae: 1.7994
# Epoch 497/500
#  1/26 [>.............................] - ETA: 0s - loss: 5.9242 - mae: 1.8850WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 484us/step - loss: 6.3120 - mae: 1.7721
# Epoch 498/500
#  1/26 [>.............................] - ETA: 0s - loss: 3.8039 - mae: 1.5351WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 527us/step - loss: 6.3034 - mae: 1.7822
# Epoch 499/500
#  1/26 [>.............................] - ETA: 0s - loss: 21.9264 - mae: 2.6844WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 486us/step - loss: 6.3014 - mae: 1.7813
# Epoch 500/500
#  1/26 [>.............................] - ETA: 0s - loss: 6.2906 - mae: 2.0716WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,mae
# 26/26 [==============================] - 0s 536us/step - loss: 6.2381 - mae: 1.7684
# CPU times: user 7.81 s, sys: 1.54 s, total: 9.35 s
# Wall time: 7.42 s

# %%
res = model.evaluate(X_test_scaled,y_test,verbose=0)[1]
res
# Out:
# 2.7995378971099854

# %% [markdown]
# ### Neural Network vs. Baseline
#
# Compare the MAE on the testing set between this Neural Network and the baseline model.

# %%
mae_test_baseline = mean_absolute_error_test_baseline
mae_test_neuralnet = res

print(f"The MAE on the test is {mae_test_neuralnet:.4f} for the Neural Network vs. {mae_test_baseline:.4f} for the baseline")
# Out:
# The MAE on the test is 2.7995 for the Neural Network vs. 6.5330 for the baseline

# %% [markdown]
# ### (2.1) Which Optimizer is the Best?

# %% [markdown]
# #### ❓Trying Different Optimizers
#
# Re-run the same model on the same data using different optimizers (in a `for` loop).
#
# For each optimizer:
# - 📉 Plot the history of the loss (MSE) and the metric (MAE)
#     - 🎁 We coded two functions: `plot_loss_mae` and `plot_loss_mse`. Which one should you use? Feel free to use it.
# - ✍️ Report the corresponding Mean Absolute Error
# - ⏳ Compute the time your Neural Net needed to fit the training set
#
# 📚 [`tensorflow.keras.optimizers`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers)

# %%
def plot_loss_mae(history):
    # Setting figures
    fig, (ax1, ax2) = plt.subplots(1,2, figsize=(13,4))

    # Create the plots
    ax1.plot(history.history['loss'])
    ax1.plot(history.history['val_loss'])

    ax2.plot(history.history['mae'])
    ax2.plot(history.history['val_mae'])

    # Set titles and labels
    ax1.set_title('Model loss')
    ax1.set_ylabel('Loss')
    ax1.set_xlabel('Epoch')

    ax2.set_title('MAE')
    ax2.set_ylabel('MAE')
    ax2.set_xlabel('Epoch')

    # Set limits for y-axes
    ax1.set_ylim(ymin=0, ymax=200)
    ax2.set_ylim(ymin=0, ymax=20)

    # Generate legends
    ax1.legend(['Train', 'Validation'], loc='best')
    ax2.legend(['Train', 'Validation'], loc='best')

    # Show grids
    ax1.grid(axis="x",linewidth=0.5)
    ax1.grid(axis="y",linewidth=0.5)

    ax2.grid(axis="x",linewidth=0.5)
    ax2.grid(axis="y",linewidth=0.5)

    plt.show()

# %%
optimizers = ['rmsprop', 'adam', 'adagrad']
results = []
for optimizer in optimizers:
    start_time = time.time()
    model = compile_model(initialize_model(),optimizer)
    
    es = EarlyStopping(patience=20,restore_best_weights=True)
    
    history = model.fit(X_train_scaled,
    y_train,
    validation_split = 0.3,
    epochs = 500,
    batch_size = 16, 
    verbose = 0, 
    callbacks = [es])
    
    res = model.evaluate(X_test_scaled,y_test)[1]
    results.append(res)
    end_time = time.time()
    plot_loss_mae(history)
# Out:
# 4/4 [==============================] - 0s 531us/step - loss: 20.6094 - mae: 2.9356
# 4/4 [==============================] - 0s 563us/step - loss: 22.5961 - mae: 3.0454
# 4/4 [==============================] - 0s 571us/step - loss: 412.2509 - mae: 17.8756

# %% [markdown]
# #### Neural Network vs. Baseline - Part 2
#
# Are your predictions better than those of the baseline model you evaluated at the beginning of the notebook?

# %%
# MAE on the testing set for different optimizers
for optimizer, result in zip(['rmsprop', 'adam', 'adagrad'], results):
    print(f"The MAE on the test set with the {optimizer} optimizer is equal to {result:.2f}")

# MAE on the testing set for the baseline model    
print("-"*5)    
print(f"The MAE on the test set with the baseline model is equal to {mae_test_baseline:.2f}")
# Out:
# The MAE on the test set with the rmsprop optimizer is equal to 2.94
# The MAE on the test set with the adam optimizer is equal to 3.05
# The MAE on the test set with the adagrad optimizer is equal to 17.88
# -----
# The MAE on the test set with the baseline model is equal to 6.53

# %% [markdown]
# #### 💡Answer
#
# <details>
#     <summary>Click me</summary>
#
# You can see that the Neural Network beat the baseline when using either `adam` or `rmsprop` as an optimizer but the result was significantly worse with the `adagrad` optimizer.
#
# **👇 The advice from the Deep Learning community is the following 👇:**
#
# 🔥 So far, our best-performing optimizer is `adam`. Maybe a mathematician specialized in numerical methods will find a better solver in the future but for the moment, Adam is your best friend and they have already been helping us achieve remarkable results.
# </details>

# %% [markdown]
# #### Next Steps for this Challenge
#
# 👩‍🎓 Do you remember the **Machine Learning > 04.Under The Hood** unit where we coded our **Gradient Descent** by choosing a specific `learning_rate`? It represents how slow/fast your algorithm learns. In other words, it controls the intensity of the change of the weights at each optimization of the NN, at each backpropagation!
#
# 🚀 Well, the **solvers** in Machine Learning and the **optimizers** in Deep Learning are advanced iterative methods relying on **hyperparameters**, and the `learning_rate` is one of them!
#
# 🤔 How can I control this `learning_rate`?
#
# ✅ Instead of calling an optimizer with a string ("adam", "rmsprop", etc.), which uses a default value for the Learning Rate, we will call 📚 [`tf.keras.optimizers`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers) objects 📚 and tailor them to our needs.
#
# 🧑🏻‍🏫 Different Learning Rates have different consequences, as shown here:
#
# <img src="https://wagon-public-datasets.s3-eu-west-1.amazonaws.com/06-DL/02-Optimizer-loss-and-fitting/learning_rate.png" alt="Learning rate" height=300>

# %% [markdown]
# ### (2.2) The Influence of the Learning Rate

# %% [markdown]
# ### Selecting an Optimizer with a Custom Learning Rate
#
# 📚 [`tf.keras.optimizers.Adam`](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/Adam)
#
# Instead of initializing the optimizer with a string, let's initialize an optimizer manually.
#
# - Instantiate an Adam optimizer with a Learning Rate of $ \alpha = 0.1$
#     - Keep the other parameters at their default values
# - Use this optimizer in the `compile_model` function
# - Train/fit the model
# - Plot the history
# - Evaluate your model

# %%
# %%time

# 1. Instantiating the Adam optimizer with a learning rate alpha = 0.1
adam = Adam(learning_rate = 0.1)

# 2. Initializing the model
model = initialize_model()

# 3. Compiling the model with the custom Adam optimizer
model = compile_model(model, adam)

# 4. Training the neural net
es = EarlyStopping(patience = 20)
history = model.fit(
    X_train_scaled,
    y_train, 
    validation_split = 0.3,
    shuffle = True,
    batch_size=16, 
    epochs = 1_000,
    callbacks = [es],
    verbose = 0
)

# 5. Plot the history and evaluate the model
res = model.evaluate(X_test_scaled, y_test)[1]
res
print(f'Mean absolute error with a learning rate of 0.1: {res:.4f}')
plot_loss_mae(history)
# Out:
# 4/4 [==============================] - 0s 475us/step - loss: 17.6966 - mae: 2.8609
# Mean absolute error with a learning rate of 0.1: 2.8609
# CPU times: user 1.96 s, sys: 214 ms, total: 2.18 s
# Wall time: 1.46 s

# %% [markdown]
# ### ❓Playing with Learning Rates
#
# Now, reproduce the same plots and results but for different Learning Rates.
#
# <details>
#     <summary>Remark</summary>
#
# There is a chance that the y-axis is too large for you to visualize some results with some Learning Rates. In that case, feel free to re-write the plot function to plot only the epochs $> 10$.
#
# </details>

# %%
learning_rates = [0.0001, 0.001, 0.01, 0.1, 1, 2]
results = []

for learning_rate in learning_rates:
    adam = Adam(learning_rate = learning_rate)
    
    model = initialize_model()
    
    model = compile_model(model, adam)
    
    es = EarlyStopping(patience = 20)
    history = model.fit(
    X_train_scaled,
    y_train, 
    validation_split = 0.3,
    shuffle = True,
    batch_size=16, 
    epochs = 1_000,
    callbacks = [es],
    verbose = 0
)
    
    res = model.evaluate(X_test_scaled, y_test)[1]
    res
    print(f'Mean absolute error with a learning rate of 0.1: {res:.4f}')
    plot_loss_mae(history)
# Out:
# 4/4 [==============================] - 0s 518us/step - loss: 19.9897 - mae: 3.3428
# Mean absolute error with a learning rate of 0.1: 3.3428
# 4/4 [==============================] - 0s 578us/step - loss: 20.3777 - mae: 2.8937
# Mean absolute error with a learning rate of 0.1: 2.8937
# 4/4 [==============================] - 0s 515us/step - loss: 20.5651 - mae: 3.0057
# Mean absolute error with a learning rate of 0.1: 3.0057
# 4/4 [==============================] - 0s 588us/step - loss: 15.8975 - mae: 2.7952
# Mean absolute error with a learning rate of 0.1: 2.7952
# 4/4 [==============================] - 0s 558us/step - loss: 83.5992 - mae: 6.5398
# Mean absolute error with a learning rate of 0.1: 6.5398
# 4/4 [==============================] - 0s 575us/step - loss: 84.5834 - mae: 6.5137
# Mean absolute error with a learning rate of 0.1: 6.5137

# %% [markdown]
# ## (3) The Loss
#
# ---
#
# ❗️It's important to clearly understand the **difference between losses and metrics**❗️
#
# - 🏋🏻‍♀️ The **Loss Functions** are computed **during the training procedure**
#     - For regression tasks, the classic Loss Functions are **(Root) Mean Squared Error** ((R)MSE), **Mean Absolute Error** (MAE), and **Mean Squared Logarithmic Error** (MSLE, as seen in the Kaggle challenge)
#     - For classification tasks, the classic Loss Functions are **Binary Crossentropy** (also known as LogLoss), **Categorical Crossentropy**, Hinge Loss, etc.
# - 🧑🏻‍🏫 The **metrics** are computed to evaluate your models, **after training them**!
#     - For regression tasks, common metrics are MSE, MAE, RMSE, Coefficient of Determination (R2), etc.
#     - For classification tasks, common metrics are Accuracy, Recall, Precision, and F1-Score
# - 👀 Notice that some metrics can also be used as Loss Functions, as long as they are differentiable! (e.g. the **MSE**)
#
# If these notions are not clear, we strongly advise reviewing **Machine Learning > 03.Performance Metrics** and **Machine Learning > 05.Model Tuning**
#
# ---
#
# ⏩ Alright, after this reminder, let's move on:

# %% [markdown]
# ### ❓Optimizing a Model with a certain Loss Function
#
# - Run the same NN, once with `mae` as the loss, and once with `mse`
# - In both cases, compare `mae_train`, `mae_val`, `mse_train`, `mse_val`

# %%
# MAE as a loss function
model = initialize_model()
model.compile(loss = 'mae', optimizer = 'adam', metrics = ['mse'])

es = EarlyStopping(patience = 20)
history = model.fit(
    X_train_scaled,
    y_train, 
    validation_split = 0.3,
    shuffle = True,
    batch_size=16, 
    epochs = 1_000,
    callbacks = [es],
    verbose = 0
)

res = model.evaluate(X_test_scaled, y_test)
# Out:
# 4/4 [==============================] - 0s 581us/step - loss: 2.7696 - mse: 16.5829

# %%
print(f"MAE_train : {min(history.history['loss']):.4f} - MSE_train : {min(history.history['mse']):.4f}")
print(f"MAE_val : {min(history.history['val_loss']):.4f} - MSE_val : {min(history.history['val_mse']):.4f}")
print(f"MAE_test : {res[0]:.4f} - MSE_val : {res[1]:.4f}")
# Out:
# MAE_train : 1.5340 - MSE_train : 6.8539
# MAE_val : 2.7387 - MSE_val : 22.1221
# MAE_test : 2.7696 - MSE_val : 16.5829

# %%
# MSE as a loss function
model = initialize_model()
model.compile(loss = 'mse', optimizer = 'adam', metrics = ['mae'])

es = EarlyStopping(patience = 20)
history = model.fit(
    X_train_scaled,
    y_train, 
    validation_split = 0.3,
    shuffle = True,
    batch_size=16, 
    epochs = 1_000,
    callbacks = [es],
    verbose = 0
)

res = model.evaluate(X_test_scaled, y_test)
# Out:
# 4/4 [==============================] - 0s 568us/step - loss: 19.8888 - mae: 2.7381

# %%
print(f"MAE_train : {min(history.history['mae']):.4f} - MSE_train : {min(history.history['loss']):.4f}")
print(f"MAE_val : {min(history.history['val_mae']):.4f} - MSE_val : {min(history.history['val_loss']):.4f}")
print(f"MAE_test : {res[1]:.4f} - MSE_val : {res[0]:.4f}")
# Out:
# MAE_train : 1.5836 - MSE_train : 4.4869
# MAE_val : 2.6703 - MSE_val : 16.0026
# MAE_test : 2.7381 - MSE_val : 19.8888

# %% [markdown]
# ### 💡Learnings
#
# 🤔 When you work on this regression task, you want to achieve the lowest MAE in the testing set at the end, right? So why wouldn't we use it directly as a Loss Function that would decrease with the number of epochs?
#
# <details>
#     <summary>Answer</summary>
#
# Well, even the Deep Learning research community is still trying to answer these types of questions rigorously.
#
# One thing is sure: in Deep Learning, you will never really reach the "global minimum" of the true Loss Function (the one computed using your entire training set as one single batch). So, in your first model (minimizing the MAE loss), your global MAE minimum has clearly **not** been reached (otherwise you could never beat it).
#
# Why? It may well be that the minimization process of the second model has performed better. Maybe because the Loss Function "energy map" is "smoother" or more "convex" in the case of MSE loss? Or maybe your hyper-parameters are best suited to the MSE than to the MAE loss?
#
# </details>

# %% [markdown]
# ## (4)  Saving and Loading a Trained Neural Network
#
# 🤯 Imagine that you trained a complex Neural Network (many layers/neurons) on a huge dataset. The parameters of your Deep Learning Model (weights and biases) are now optimized and you would like to share these weights with a teammate who wants to predict a new data point. Would you give this person your notebook for them to run it and then predict the new data point? Hell no, we have a much better solution:
# - 💾 Save the weights of the optimized Neural Network
# - 🤝 Your friend/colleague/teammate/classmate can use them to predict a new data point

# %% [markdown]
# ### ❓Training a Good Model
#
# - Try to reach an MAE on the testing set that is lower than 5 (_feel free to re-create the architecture and redefine your compiling parameters in this section!_)
#     - Remember: we are predicting house prices, so a mistake of less than 5.000 USD is already good in the real estate industry)
#
# - Whether you managed to reach it or not, move on to the "Saving a Model" section after a few attempts.

# %%
model.add(layers.Dense(10, activation='relu', input_dim=X_train_scaled.shape[-1]))
model.add(layers.Dense(7, activation='relu'))
model.add(layers.Dense(1, activation='linear'))

adam = Adam(learning_rate = 0.01)

model = compile_model(model, adam)

es = EarlyStopping(patience = 20)

history = model.fit(
    X_train_scaled, 
    y_train, 
    validation_split = 0.3,
    shuffle = True,
    batch_size=16, 
    epochs = 1000,
    callbacks = [es], 
    verbose = 0
)

plot_loss_mae(history)

mae_test = model.evaluate(X_test_scaled, y_test)[1]
mae_test
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 20.1032 - mae: 2.7678
# 2.7678143978118896

# %%
from nbresult import ChallengeResult

result = ChallengeResult(
    'solution',
    mae_test = mae_test
)

result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /Users/taniagretton/.pyenv/versions/3.10.6/envs/lewagon/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/taniagretton/code/TaniaGretton/data-finetune-your-neural-network/tests
# plugins: asyncio-0.19.0, typeguard-2.13.3, anyio-3.6.2
# asyncio: mode=strict
# collecting ... collected 1 item
#
# test_solution.py::TestSolution::test_is_score_beat_baseline PASSED       [100%]
#
# ============================== 1 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/solution.pickle
#
# git commit -m 'Completed solution step'
#
# git push origin master

# %% [markdown]
# ### ❓Saving a Model
#
# 📚 [`tf.keras.models.save_model`](https://www.tensorflow.org/api_docs/python/tf/keras/models/save_model)
#
# Save your model using the `.save_model(model, 'name_of_my_model')` method.

# %%
models.save_model(model, 'my_model')
# Out:
# INFO:tensorflow:Assets written to: my_model/assets

# %% [markdown]
# ### ❓Loading a Model
#
# 📚 [`tf.keras.models.load_model`](https://www.tensorflow.org/api_docs/python/tf/keras/models/load_model)
#
# - Load the model that you've just saved using `.load_model('name_of_your_model')` and store it into a variable called `loaded_model`
# - Evaluate it on the testing data to check that it gives the same result as before

# %%
loaded_model = models.load_model('my_model')
loaded_model

# %%
loaded_model.summary()
# Out:
# Model: "sequential_34"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_105 (Dense)           (None, 10)                140
#
#  dense_106 (Dense)           (None, 7)                 77
#
#  dense_107 (Dense)           (None, 1)                 8
#
#  dense_108 (Dense)           (None, 10)                20
#
#  dense_109 (Dense)           (None, 7)                 77
#
#  dense_110 (Dense)           (None, 1)                 8
#
# =================================================================
# Total params: 330
# Trainable params: 330
# Non-trainable params: 0
# _________________________________________________________________

# %%
res_loaded_model = loaded_model.evaluate(X_test_scaled, y_test, verbose = 0)[1]
res_loaded_model
# Out:
# 2.7678143978118896

# %% [markdown]
# ## (5) (Optional) Exponential Decay
#
# ❗️Warning❗️
#
# - This section is optional and for advanced practitioners
# - The next question is not essential and can be indeed skipped as many algorithms can be run without such optimization
#
# 🧑🏻‍🏫 Instead of keeping a fixed Learning Rate, you can change it from one iteration to the other, with the intuition that at first, you need a large Learning Rate to learn fast, and as the Neural Network converges and gets closer to the minimum of the Loss Function, you can decrease the value of the Learning Rate. This is called a **scheduler**.

# %% [markdown]
# ### ❓The Exponential Decay Scheduler
#
# Use the 📚 [Exponential Decay Scheduler](https://www.tensorflow.org/api_docs/python/tf/keras/optimizers/schedules/ExponentialDecay) 📚 in the `adam` optimizer, and run it on the previous data.
#
# Start with the following:
#
# ```python
# initial_learning_rate = 0.001 # start with default Adam value
#
# lr_schedule = ExponentialDecay(
#     # Every 5000 iterations, multiply the learning rate by 0.7
#     initial_learning_rate, decay_steps = 5000, decay_rate = 0.7,
# )
# ```

# %%
X_train.shape[0] * 0.7 / 16
# Out:
# 17.674999999999997

# %%
initial_learning_rate = 0.001

lr_schedule = ExponentialDecay(
    initial_learning_rate, 
    decay_steps = 5000,    
    decay_rate = 0.7,      
)

adam = Adam(learning_rate=lr_schedule)

model = initialize_model()
model = compile_model(model, adam)

es = EarlyStopping(patience=20)

history = model.fit(
    X_train_scaled,
    y_train, 
    validation_split = 0.3,
    shuffle = True,
    batch_size = 16, 
    epochs = 1000, 
    callbacks = [es], 
    verbose = 0
)

res = model.evaluate(X_test_scaled, y_test)[1]
plot_loss_mae(history)
# Out:
# 4/4 [==============================] - 0s 592us/step - loss: 18.4626 - mae: 2.9461

# %% [markdown]
# ## 🏁 Congratulations!
#
# 💾 Do not forget to `git add/commit/push` your notebook...
#
# 🚀 ... and move to the next challenge!
#
# ---
#
# **Further reading after your bootcamp:**
#
# The **Boston Housing Dataset** was deprecated by Scikit-Learn for ethical reasons, and TensorFlow may also replace it in the future.
#
# A certain M. Carlisle wrote a 12-min read article called ["Racist Data Destruction"](https://medium.com/@docintangible/racist-data-destruction-113e3eff54a8) to investigate this problem.
